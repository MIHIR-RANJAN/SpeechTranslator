# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.4-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 2.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests>=2.26.0 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from SpeechRecognition) (2.28.2)
# Requirement already satisfied: typing-extensions in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from SpeechRecognition) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.14)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
#basic speech recognition once
import speech_recognition as sr

def record_and_recognize_speech():
    # Initialize the recognizer
    recognizer = sr.Recognizer()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for n seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=10)
        print("Microphone calibrated. Start speaking...")

        # Capture the audio from the microphone
        audio = recognizer.listen(source)

        try:
            # Recognize the speech using Google Web Speech API
            print("Recognizing speech...")
            text = recognizer.recognize_google(audio)
            print(f"Text recognized: {text}")
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
        except sr.UnknownValueError:
            print("Could not understand the audio")

if __name__ == "__main__":
    record_and_recognize_speech()
# Out:
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Recognizing speech...
# Text recognized: hello fox this is your captain speaking I am Mihir Ranjan welcome to Emirates 101 we love you all welcome about

# %%
#infinite loop for speech recognition and output 
import speech_recognition as sr

def real_time_speech_recognition():
    # Initialize the recognizer
    recognizer = sr.Recognizer()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for n seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=2)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone
            audio = recognizer.listen(source)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

if __name__ == "__main__":
    real_time_speech_recognition()
# Out:
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: Firefox this is your captain speaking and we like to thank all of you in this wonderful journey with us and we hope you guys are gonna do best with us so please please be seated and Let's create the thing
# Listening...
# Text recognized: Ranjan yes yes yes Niranjan speaking and we will love to see you around and let's not talk much and let's not see much and that's not keep much and let's not see much this is wonderful fucking place let's just fuck everybody and do nothing
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 29
#      26                 print("Could not understand the audio")
#      28 if __name__ == "__main__":
# ---> 29     real_time_speech_recognition()
#
# Cell In[10], line 21, in real_time_speech_recognition()
#      17 audio = recognizer.listen(source)
#      19 try:
#      20     # Recognize the speech using Google Web Speech API
# ---> 21     text = recognizer.recognize_google(audio)
#      22     print(f"Text recognized: {text}")
#      23 except sr.RequestError as e:
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/recognizers/google.py:256, in recognize_legacy(recognizer, audio_data, key, language, pfilter, show_all, with_confidence, endpoint)
#     251 request_builder = create_request_builder(
#     252     endpoint=endpoint, key=key, language=language, filter_level=pfilter
#     253 )
#     254 request = request_builder.build(audio_data)
# --> 256 response_text = obtain_transcription(
#     257     request, timeout=recognizer.operation_timeout
#     258 )
#     260 output_parser = OutputParser(
#     261     show_all=show_all, with_confidence=with_confidence
#     262 )
#     263 return output_parser.parse(response_text)
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/recognizers/google.py:215, in obtain_transcription(request, timeout)
#     213 def obtain_transcription(request: Request, timeout: int) -> str:
#     214     try:
# --> 215         response = urlopen(request, timeout=timeout)
#     216     except HTTPError as e:
#     217         raise RequestError("recognition request failed: {}".format(e.reason))
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#infinite loop code for continous recognition and output
import speech_recognition as sr
import time

def real_time_speech_recognition():
    # Initialize the recognizer
    recognizer = sr.Recognizer()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for n seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in n-second chunks
            audio = recognizer.record(source, duration=2)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    real_time_speech_recognition()
# Out:
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: welcome to
# Listening...
# Text recognized: world welcome to
# Listening...
# Text recognized: I do understand
# Listening...
# Text recognized: Mihir Ranjan
# Listening...
# Text recognized: what the fuck
# Listening...
# Text recognized: oh my God
# Listening...
# Text recognized: oh yes
# Listening...
# Text recognized: no no no we
# Listening...
# Text recognized: it is very difficult
# Listening...
# Text recognized: try to understand
# Listening...
# Text recognized: of course
# Listening...
# Text recognized: of course
# Listening...
# Text recognized: you are a bitch
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: daddy's home
# Listening...
# Text recognized: daddy's
# Listening...
# Text recognized: oh my God
# Listening...
# Text recognized: let's do it again
# Listening...
# Text recognized: let's do
# Listening...
# Text recognized: let's
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 33
#      30             time.sleep(0.1)
#      32 if __name__ == "__main__":
# ---> 33     real_time_speech_recognition()
#
# Cell In[18], line 18, in real_time_speech_recognition()
#      16 print("Listening...")
#      17 # Capture the audio from the microphone in n-second chunks
# ---> 18 audio = recognizer.record(source, duration=2)
#      20 try:
#      21     # Recognize the speech using Google Web Speech API
#      22     text = recognizer.recognize_google(audio)
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:361, in Recognizer.record(self, source, duration, offset)
#     358     if offset_time > offset:
#     359         offset_reached = True
# --> 361 buffer = source.stream.read(source.CHUNK)
#     362 if len(buffer) == 0: break
#     364 if offset_reached or not offset:
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~/anaconda3/lib/python3.10/site-packages/pyaudio/__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
#speech recognition - stops at command 
import speech_recognition as sr
import time

def real_time_speech_recognition():
    # Initialize the recognizer
    recognizer = sr.Recognizer()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for 2 seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=4)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in 0.5-second chunks
            audio = recognizer.record(source, duration=2)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
                
                # Check if the recognized text is "stop program"
                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    real_time_speech_recognition()
# Out:
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: hello folks
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: I can understand
# Listening...
# Text recognized: I cannot understand
# Listening...
# Text recognized: I
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: hey hey hey
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: this is
# Listening...
# Text recognized: this is
# Listening...
# Text recognized: Mihir
# Listening...
# Text recognized: Ranjan
# Listening...
# Text recognized: stop program
# Stop command recognized. Exiting program.

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 776.7 kB/s eta 0:00:00 0:00:01
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.4 MB/s eta 0:00:00
# Collecting hstspreload
#   Downloading hstspreload-2024.7.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: sniffio in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting idna==2.*
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 945.8 kB/s eta 0:00:00 0:00:01
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.12.7)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 1.7 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17414 sha256=f49132c74d29c37ef646131bb5abb7492738c2e8c7678feab0e0b749bc829998
#   Stored in directory: /Users/doctorranjan/Library/Caches/pip/wheels/54/ca/27/562b6eac3a495887e4b44bac3a1efe925fa603d085ba89a21d
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.1 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.28.2 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.7.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#basic tranlation manually
import speech_recognition as sr
import time
from googletrans import Translator

def real_time_speech_recognition():
    # Initialize the recognizer and translator
    recognizer = sr.Recognizer()
    translator = Translator()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for 2 seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in 0.5-second chunks
            audio = recognizer.record(source, duration=4)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
                
                # Translate the recognized text
                translated_text = translator.translate(text, dest='es').text  # Translate to Spanish (es)
                print(f"Translated text: {translated_text}")

                # Check if the recognized text is "stop program"
                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    real_time_speech_recognition()
# Out:
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: hello fox this is a captain speaking
# Translated text: Hola Fox Este es un capitán hablando
# Listening...
# Text recognized: Niranjan new captain
# Translated text: Niranjan nuevo capitán
# Listening...
# Text recognized: welcome to the Emirates 111
# Translated text: Bienvenido a los Emiratos 111
# Listening...
# Text recognized: welcome to the Emirates 101
# Translated text: Bienvenido a los Emiratos 101
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: where are you
# Translated text: dónde estás
# Listening...
# Text recognized: what is your name
# Translated text: cómo te llamas
# Listening...
# Text recognized: I don't understand what do you mean by this
# Translated text: No entiendo a qué te refieres con esto
# Listening...
# Text recognized: Hola let's do this
# Translated text: Hola hagamos esto
# Listening...
# Text recognized: stop program
# Translated text: programa de parada
# Stop command recognized. Exiting program.

# %%
#basic "take1" tranlate to other language - it ask initially what language to change but have to put manually
import speech_recognition as sr
import time
from googletrans import Translator

def real_time_speech_recognition(target_language):
    # Initialize the recognizer and translator
    recognizer = sr.Recognizer()
    translator = Translator()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for 5 seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in 0.5-second chunks
            audio = recognizer.record(source, duration=4)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
                
                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language).text
                print(f"Translated text: {translated_text}")

                # Check if the recognized text is "stop program"
                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    # List of supported languages
    supported_languages = {
        'af': 'Afrikaans', 'sq': 'Albanian', 'ar': 'Arabic', 'hy': 'Armenian', 'bn': 'Bengali', 'bs': 'Bosnian',
        'ca': 'Catalan', 'ce': 'Chechen', 'ny': 'Chichewa', 'zh-cn': 'Chinese (Simplified)', 'zh-tw': 'Chinese (Traditional)',
        'co': 'Corsican', 'hr': 'Croatian', 'cs': 'Czech', 'da': 'Danish', 'nl': 'Dutch', 'en': 'English', 'eo': 'Esperanto',
        'et': 'Estonian', 'tl': 'Filipino', 'fi': 'Finnish', 'fr': 'French', 'fy': 'Frisian', 'gl': 'Galician', 'ka': 'Georgian',
        'de': 'German', 'el': 'Greek', 'gu': 'Gujarati', 'ht': 'Haitian Creole', 'ha': 'Hausa', 'haw': 'Hawaiian', 'he': 'Hebrew',
        'hi': 'Hindi', 'hu': 'Hungarian', 'is': 'Icelandic', 'ig': 'Igbo', 'id': 'Indonesian', 'ia': 'Interlingua', 'ie': 'Interlingue',
        'iu': 'Inuktitut', 'ie': 'Irish', 'it': 'Italian', 'ja': 'Japanese', 'jw': 'Javanese', 'kn': 'Kannada', 'kk': 'Kazakh',
        'km': 'Khmer', 'ki': 'Kinyarwanda', 'rw': 'Kinyarwanda', 'ko': 'Korean', 'ku': 'Kurdish', 'lo': 'Lao', 'la': 'Latin',
        'lv': 'Latvian', 'lt': 'Lithuanian', 'lb': 'Luxembourgish', 'mk': 'Macedonian', 'mg': 'Malagasy', 'ml': 'Malayalam',
        'mt': 'Maltese', 'mi': 'Maori', 'mr': 'Marathi', 'my': 'Myanmar (Burmese)', 'mn': 'Mongolian', 'my': 'Nepali',
        'no': 'Norwegian', 'or': 'Odia (Oriya)', 'ps': 'Pashto', 'fa': 'Persian', 'pl': 'Polish', 'pt': 'Portuguese',
        'pa': 'Punjabi', 'qu': 'Quechua', 'ro': 'Romanian', 'ru': 'Russian', 'sm': 'Samoan', 'sg': 'Sango', 'sa': 'Sanskrit',
        'sc': 'Sardinian', 'sr': 'Serbian', 'st': 'Sesotho', 'sn': 'Shona', 'sd': 'Sindhi', 'si': 'Sinhala', 'sk': 'Slovak',
        'sl': 'Slovenian', 'so': 'Somali', 'es': 'Spanish', 'su': 'Sundanese', 'sw': 'Swahili', 'sv': 'Swedish', 'tl': 'Tagalog',
        'tg': 'Tajik', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai', 'ti': 'Tigrinya', 'to': 'Tonga', 'tr': 'Turkish',
        'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese', 'cy': 'Welsh', 'xh': 'Xhosa', 'yi': 'Yiddish', 'yo': 'Yoruba',
        'zu': 'Zulu'
    }

    # Display supported languages
    print("Supported languages:")
    for code, language in supported_languages.items():
        print(f"{code}: {language}")

    # Prompt the user to enter a language code
    target_language = input("Enter the language code for translation (e.g., 'es' for Spanish): ").strip().lower()

    # Validate the language code
    if target_language not in supported_languages:
        print("Unsupported language code. Exiting program.")
    else:
        real_time_speech_recognition(target_language)
# Out:
# Supported languages:
# af: Afrikaans
# sq: Albanian
# ar: Arabic
# hy: Armenian
# bn: Bengali
# bs: Bosnian
# ca: Catalan
# ce: Chechen
# ny: Chichewa
# zh-cn: Chinese (Simplified)
# zh-tw: Chinese (Traditional)
# co: Corsican
# hr: Croatian
# cs: Czech
# da: Danish
# nl: Dutch
# en: English
# eo: Esperanto
# et: Estonian
# tl: Tagalog
# fi: Finnish
# fr: French
# fy: Frisian
# gl: Galician
# ka: Georgian
# de: German
# el: Greek
# gu: Gujarati
# ht: Haitian Creole
# ha: Hausa
# haw: Hawaiian
# he: Hebrew
# hi: Hindi
# hu: Hungarian
# is: Icelandic
# ig: Igbo
# id: Indonesian
# ia: Interlingua
# ie: Irish
# iu: Inuktitut
# it: Italian
# ja: Japanese
# jw: Javanese
# kn: Kannada
# kk: Kazakh
# km: Khmer
# ki: Kinyarwanda
# rw: Kinyarwanda
# ko: Korean
# ku: Kurdish
# lo: Lao
# la: Latin
# lv: Latvian
# lt: Lithuanian
# lb: Luxembourgish
# mk: Macedonian
# mg: Malagasy
# ml: Malayalam
# mt: Maltese
# mi: Maori
# mr: Marathi
# my: Nepali
# mn: Mongolian
# no: Norwegian
# or: Odia (Oriya)
# ps: Pashto
# fa: Persian
# pl: Polish
# pt: Portuguese
# pa: Punjabi
# qu: Quechua
# ro: Romanian
# ru: Russian
# sm: Samoan
# sg: Sango
# sa: Sanskrit
# sc: Sardinian
# sr: Serbian
# st: Sesotho
# sn: Shona
# sd: Sindhi
# si: Sinhala
# sk: Slovak
# sl: Slovenian
# so: Somali
# es: Spanish
# su: Sundanese
# sw: Swahili
# sv: Swedish
# tg: Tajik
# ta: Tamil
# te: Telugu
# th: Thai
# ti: Tigrinya
# to: Tonga
# tr: Turkish
# uk: Ukrainian
# ur: Urdu
# vi: Vietnamese
# cy: Welsh
# xh: Xhosa
# yi: Yiddish
# yo: Yoruba
# zu: Zulu
# Enter the language code for translation (e.g., 'es' for Spanish): zu
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: I am Mihir Ranjan
# Translated text: Em yi-ranja ye-biographical
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: this is your captain speaking
# Translated text: Lokhu ukaputeni wakho uyakhuluma
# Listening...
# Text recognized: I know what do you mean by this bitch
# Translated text: Ngiyazi ukuthi usho ukuthini ngale bitch
# Listening...
# Text recognized: try to understand me
# Translated text: zama ukungiqonda
# Listening...
# Text recognized: no no you're not at all understand
# Translated text: cha, cha awuqondi nhlobo
# Listening...
# Text recognized: please let's catch up
# Translated text: ngicela usibambe
# Listening...
# Text recognized: cool cool
# Translated text: Mahhala
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: stop program
# Translated text: Stop Program
# Stop command recognized. Exiting program.

# %%
#basic"take2" tranlate to other language - it ask initially what language to change but have to put manually
import speech_recognition as sr
import time
from googletrans import Translator

def real_time_speech_recognition(target_language):
    # Initialize the recognizer and translator
    recognizer = sr.Recognizer()
    translator = Translator()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for 5 seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in 0.5-second chunks
            audio = recognizer.record(source, duration=4)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
                
                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language).text
                print(f"Translated text: {translated_text}")

                # Check if the recognized text is "stop program"
                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    # List of supported languages
    supported_languages = {
        'af': 'Afrikaans', 'sq': 'Albanian', 'ar': 'Arabic', 'hy': 'Armenian', 'bn': 'Bengali', 'bs': 'Bosnian',
        'ca': 'Catalan', 'ce': 'Chechen', 'ny': 'Chichewa', 'zh-cn': 'Chinese (Simplified)', 'zh-tw': 'Chinese (Traditional)',
        'co': 'Corsican', 'hr': 'Croatian', 'cs': 'Czech', 'da': 'Danish', 'nl': 'Dutch', 'en': 'English', 'eo': 'Esperanto',
        'et': 'Estonian', 'tl': 'Filipino', 'fi': 'Finnish', 'fr': 'French', 'fy': 'Frisian', 'gl': 'Galician', 'ka': 'Georgian',
        'de': 'German', 'el': 'Greek', 'gu': 'Gujarati', 'ht': 'Haitian Creole', 'ha': 'Hausa', 'haw': 'Hawaiian', 'he': 'Hebrew',
        'hi': 'Hindi', 'hu': 'Hungarian', 'is': 'Icelandic', 'ig': 'Igbo', 'id': 'Indonesian', 'ia': 'Interlingua', 'ie': 'Interlingue',
        'iu': 'Inuktitut', 'ie': 'Irish', 'it': 'Italian', 'ja': 'Japanese', 'jw': 'Javanese', 'kn': 'Kannada', 'kk': 'Kazakh',
        'km': 'Khmer', 'ki': 'Kinyarwanda', 'rw': 'Kinyarwanda', 'ko': 'Korean', 'ku': 'Kurdish', 'lo': 'Lao', 'la': 'Latin',
        'lv': 'Latvian', 'lt': 'Lithuanian', 'lb': 'Luxembourgish', 'mk': 'Macedonian', 'mg': 'Malagasy', 'ml': 'Malayalam',
        'mt': 'Maltese', 'mi': 'Maori', 'mr': 'Marathi', 'my': 'Myanmar (Burmese)', 'mn': 'Mongolian', 'my': 'Nepali',
        'no': 'Norwegian', 'or': 'Odia (Oriya)', 'ps': 'Pashto', 'fa': 'Persian', 'pl': 'Polish', 'pt': 'Portuguese',
        'pa': 'Punjabi', 'qu': 'Quechua', 'ro': 'Romanian', 'ru': 'Russian', 'sm': 'Samoan', 'sg': 'Sango', 'sa': 'Sanskrit',
        'sc': 'Sardinian', 'sr': 'Serbian', 'st': 'Sesotho', 'sn': 'Shona', 'sd': 'Sindhi', 'si': 'Sinhala', 'sk': 'Slovak',
        'sl': 'Slovenian', 'so': 'Somali', 'es': 'Spanish', 'su': 'Sundanese', 'sw': 'Swahili', 'sv': 'Swedish', 'tl': 'Tagalog',
        'tg': 'Tajik', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai', 'ti': 'Tigrinya', 'to': 'Tonga', 'tr': 'Turkish',
        'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese', 'cy': 'Welsh', 'xh': 'Xhosa', 'yi': 'Yiddish', 'yo': 'Yoruba',
        'zu': 'Zulu'
    }

    # Display supported languages
    print("Supported languages:")
    for code, language in supported_languages.items():
        print(f"{code}: {language}")

    # Prompt the user to enter a language code
    target_language = input("Enter the language code for translation (e.g., 'es' for Spanish): ").strip().lower()

    # Validate the language code
    if target_language not in supported_languages:
        print("Unsupported language code. Exiting program.")
    else:
        real_time_speech_recognition(target_language)
# Out:
# Supported languages:
# af: Afrikaans
# sq: Albanian
# ar: Arabic
# hy: Armenian
# bn: Bengali
# bs: Bosnian
# ca: Catalan
# ce: Chechen
# ny: Chichewa
# zh-cn: Chinese (Simplified)
# zh-tw: Chinese (Traditional)
# co: Corsican
# hr: Croatian
# cs: Czech
# da: Danish
# nl: Dutch
# en: English
# eo: Esperanto
# et: Estonian
# tl: Tagalog
# fi: Finnish
# fr: French
# fy: Frisian
# gl: Galician
# ka: Georgian
# de: German
# el: Greek
# gu: Gujarati
# ht: Haitian Creole
# ha: Hausa
# haw: Hawaiian
# he: Hebrew
# hi: Hindi
# hu: Hungarian
# is: Icelandic
# ig: Igbo
# id: Indonesian
# ia: Interlingua
# ie: Irish
# iu: Inuktitut
# it: Italian
# ja: Japanese
# jw: Javanese
# kn: Kannada
# kk: Kazakh
# km: Khmer
# ki: Kinyarwanda
# rw: Kinyarwanda
# ko: Korean
# ku: Kurdish
# lo: Lao
# la: Latin
# lv: Latvian
# lt: Lithuanian
# lb: Luxembourgish
# mk: Macedonian
# mg: Malagasy
# ml: Malayalam
# mt: Maltese
# mi: Maori
# mr: Marathi
# my: Nepali
# mn: Mongolian
# no: Norwegian
# or: Odia (Oriya)
# ps: Pashto
# fa: Persian
# pl: Polish
# pt: Portuguese
# pa: Punjabi
# qu: Quechua
# ro: Romanian
# ru: Russian
# sm: Samoan
# sg: Sango
# sa: Sanskrit
# sc: Sardinian
# sr: Serbian
# st: Sesotho
# sn: Shona
# sd: Sindhi
# si: Sinhala
# sk: Slovak
# sl: Slovenian
# so: Somali
# es: Spanish
# su: Sundanese
# sw: Swahili
# sv: Swedish
# tg: Tajik
# ta: Tamil
# te: Telugu
# th: Thai
# ti: Tigrinya
# to: Tonga
# tr: Turkish
# uk: Ukrainian
# ur: Urdu
# vi: Vietnamese
# cy: Welsh
# xh: Xhosa
# yi: Yiddish
# yo: Yoruba
# zu: Zulu
# Enter the language code for translation (e.g., 'es' for Spanish): hi
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: mera naam kya hai
# Translated text: मेरा नाम क्या है
# Listening...
# Text recognized: who are you
# Translated text: आप कौन हैं
# Listening...
# Text recognized: welcome to my world
# Translated text: मेरी दुनिया में आपका स्वागत है
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: fuck
# Translated text: लानत है
# Listening...
# Text recognized: motherfucker
# Translated text: कमीने
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: ok it's good it's good it's good
# Translated text: ठीक है यह अच्छा है यह अच्छा है यह अच्छा है
# Listening...
# Text recognized: stop program
# Translated text: बंद कार्यक्रम
# Stop command recognized. Exiting program.

# %%
#basic"take3" tranlate to other language - it ask initially what language to change but have to put manually
import speech_recognition as sr
import time
from googletrans import Translator

def real_time_speech_recognition(target_language):
    # Initialize the recognizer and translator
    recognizer = sr.Recognizer()
    translator = Translator()

    # Use the microphone as the source for input
    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        # Listen for 5 seconds and create the ambient noise energy level
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            # Capture the audio from the microphone in 0.5-second chunks
            audio = recognizer.record(source, duration=4)

            try:
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")
                
                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language).text
                print(f"Translated text: {translated_text}")

                # Check if the recognized text is "stop program"
                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            # Sleep for a short time to avoid overlapping of audio chunks
            time.sleep(0.1)

if __name__ == "__main__":
    # List of supported languages
    supported_languages = {
        'af': 'Afrikaans', 'sq': 'Albanian', 'ar': 'Arabic', 'hy': 'Armenian', 'bn': 'Bengali', 'bs': 'Bosnian',
        'ca': 'Catalan', 'ce': 'Chechen', 'ny': 'Chichewa', 'zh-cn': 'Chinese (Simplified)', 'zh-tw': 'Chinese (Traditional)',
        'co': 'Corsican', 'hr': 'Croatian', 'cs': 'Czech', 'da': 'Danish', 'nl': 'Dutch', 'en': 'English', 'eo': 'Esperanto',
        'et': 'Estonian', 'tl': 'Filipino', 'fi': 'Finnish', 'fr': 'French', 'fy': 'Frisian', 'gl': 'Galician', 'ka': 'Georgian',
        'de': 'German', 'el': 'Greek', 'gu': 'Gujarati', 'ht': 'Haitian Creole', 'ha': 'Hausa', 'haw': 'Hawaiian', 'he': 'Hebrew',
        'hi': 'Hindi', 'hu': 'Hungarian', 'is': 'Icelandic', 'ig': 'Igbo', 'id': 'Indonesian', 'ia': 'Interlingua', 'ie': 'Interlingue',
        'iu': 'Inuktitut', 'ie': 'Irish', 'it': 'Italian', 'ja': 'Japanese', 'jw': 'Javanese', 'kn': 'Kannada', 'kk': 'Kazakh',
        'km': 'Khmer', 'ki': 'Kinyarwanda', 'rw': 'Kinyarwanda', 'ko': 'Korean', 'ku': 'Kurdish', 'lo': 'Lao', 'la': 'Latin',
        'lv': 'Latvian', 'lt': 'Lithuanian', 'lb': 'Luxembourgish', 'mk': 'Macedonian', 'mg': 'Malagasy', 'ml': 'Malayalam',
        'mt': 'Maltese', 'mi': 'Maori', 'mr': 'Marathi', 'my': 'Myanmar (Burmese)', 'mn': 'Mongolian', 'my': 'Nepali',
        'no': 'Norwegian', 'or': 'Odia (Oriya)', 'ps': 'Pashto', 'fa': 'Persian', 'pl': 'Polish', 'pt': 'Portuguese',
        'pa': 'Punjabi', 'qu': 'Quechua', 'ro': 'Romanian', 'ru': 'Russian', 'sm': 'Samoan', 'sg': 'Sango', 'sa': 'Sanskrit',
        'sc': 'Sardinian', 'sr': 'Serbian', 'st': 'Sesotho', 'sn': 'Shona', 'sd': 'Sindhi', 'si': 'Sinhala', 'sk': 'Slovak',
        'sl': 'Slovenian', 'so': 'Somali', 'es': 'Spanish', 'su': 'Sundanese', 'sw': 'Swahili', 'sv': 'Swedish', 'tl': 'Tagalog',
        'tg': 'Tajik', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai', 'ti': 'Tigrinya', 'to': 'Tonga', 'tr': 'Turkish',
        'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese', 'cy': 'Welsh', 'xh': 'Xhosa', 'yi': 'Yiddish', 'yo': 'Yoruba',
        'zu': 'Zulu'
    }

    # Display supported languages
    print("Supported languages:")
    for code, language in supported_languages.items():
        print(f"{code}: {language}")

    # Prompt the user to enter a language code
    target_language = input("Enter the language code for translation (e.g., 'es' for Spanish): ").strip().lower()

    # Validate the language code
    if target_language not in supported_languages:
        print("Unsupported language code. Exiting program.")
    else:
        real_time_speech_recognition(target_language)
# Out:
# Supported languages:
# af: Afrikaans
# sq: Albanian
# ar: Arabic
# hy: Armenian
# bn: Bengali
# bs: Bosnian
# ca: Catalan
# ce: Chechen
# ny: Chichewa
# zh-cn: Chinese (Simplified)
# zh-tw: Chinese (Traditional)
# co: Corsican
# hr: Croatian
# cs: Czech
# da: Danish
# nl: Dutch
# en: English
# eo: Esperanto
# et: Estonian
# tl: Tagalog
# fi: Finnish
# fr: French
# fy: Frisian
# gl: Galician
# ka: Georgian
# de: German
# el: Greek
# gu: Gujarati
# ht: Haitian Creole
# ha: Hausa
# haw: Hawaiian
# he: Hebrew
# hi: Hindi
# hu: Hungarian
# is: Icelandic
# ig: Igbo
# id: Indonesian
# ia: Interlingua
# ie: Irish
# iu: Inuktitut
# it: Italian
# ja: Japanese
# jw: Javanese
# kn: Kannada
# kk: Kazakh
# km: Khmer
# ki: Kinyarwanda
# rw: Kinyarwanda
# ko: Korean
# ku: Kurdish
# lo: Lao
# la: Latin
# lv: Latvian
# lt: Lithuanian
# lb: Luxembourgish
# mk: Macedonian
# mg: Malagasy
# ml: Malayalam
# mt: Maltese
# mi: Maori
# mr: Marathi
# my: Nepali
# mn: Mongolian
# no: Norwegian
# or: Odia (Oriya)
# ps: Pashto
# fa: Persian
# pl: Polish
# pt: Portuguese
# pa: Punjabi
# qu: Quechua
# ro: Romanian
# ru: Russian
# sm: Samoan
# sg: Sango
# sa: Sanskrit
# sc: Sardinian
# sr: Serbian
# st: Sesotho
# sn: Shona
# sd: Sindhi
# si: Sinhala
# sk: Slovak
# sl: Slovenian
# so: Somali
# es: Spanish
# su: Sundanese
# sw: Swahili
# sv: Swedish
# tg: Tajik
# ta: Tamil
# te: Telugu
# th: Thai
# ti: Tigrinya
# to: Tonga
# tr: Turkish
# uk: Ukrainian
# ur: Urdu
# vi: Vietnamese
# cy: Welsh
# xh: Xhosa
# yi: Yiddish
# yo: Yoruba
# zu: Zulu
# Enter the language code for translation (e.g., 'es' for Spanish): en
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: mera naam Mihir Ranjan hai
# Translated text: My name is Mihir Ranjan
# Listening...
# Text recognized: aap kaun ho
# Translated text: Who are you
# Listening...
# Text recognized: aapka kam kya hai yahan per
# Translated text: What is your job here
# Listening...
# Text recognized: yah Ek Vidyalay hai
# Translated text: it is a school
# Listening...
# Text recognized: Nenu Mihir Ranjan
# Translated text: I am Mihir Ramadan
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: he Mandira
# Translated text: Hey temple
# Listening...
# Text recognized: oh
# Translated text: oh
# Listening...
# Text recognized: stop program
# Translated text: stop program
# Stop command recognized. Exiting program.

# %%
import speech_recognition as sr
import time
from googletrans import Translator

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translation."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=4)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(0.1)

if __name__ == "__main__":
    # Display supported languages
    print("Supported languages:")
    for name in language_map.keys():
        print(name.capitalize())

    # Prompt user to speak the target language
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please speak the name of the language you want to translate to (e.g., 'English', 'Hindi'):")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
# Out:
# Supported languages:
# Afrikaans
# Albanian
# Arabic
# Armenian
# Bengali
# Bosnian
# Catalan
# Chechen
# Chichewa
# Chinese simplified
# Chinese traditional
# Corsican
# Croatian
# Czech
# Danish
# Dutch
# English
# Esperanto
# Estonian
# Filipino
# Finnish
# French
# Frisian
# Galician
# Georgian
# German
# Greek
# Gujarati
# Haitian creole
# Hausa
# Hawaiian
# Hebrew
# Hindi
# Hungarian
# Icelandic
# Igbo
# Indonesian
# Interlingua
# Interlingue
# Inuktitut
# Irish
# Italian
# Japanese
# Javanese
# Kannada
# Kazakh
# Khmer
# Kinyarwanda
# Korean
# Kurdish
# Lao
# Latin
# Latvian
# Lithuanian
# Luxembourgish
# Macedonian
# Malagasy
# Malayalam
# Maltese
# Maori
# Marathi
# Myanmar
# Mongolian
# Nepali
# Norwegian
# Odia
# Pashto
# Persian
# Polish
# Portuguese
# Punjabi
# Quechua
# Romanian
# Russian
# Samoan
# Sango
# Sanskrit
# Sardinian
# Serbian
# Sesotho
# Shona
# Sindhi
# Sinhala
# Slovak
# Slovenian
# Somali
# Spanish
# Sundanese
# Swahili
# Swedish
# Tagalog
# Tajik
# Tamil
# Telugu
# Thai
# Tigrinya
# Tonga
# Turkish
# Ukrainian
# Urdu
# Vietnamese
# Welsh
# Xhosa
# Yiddish
# Yoruba
# Zulu
# Please speak the name of the language you want to translate to (e.g., 'English', 'Hindi'):
# Language spoken: Swedish
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: hello I
# Translated text: Hej jag
# Listening...
# Text recognized: I am hi Ranjan
# Translated text: Jag är hej ranjan
# Listening...
# Text recognized: I am Mihir Ranjan
# Translated text: Em är en biografisk ranja
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: what is your name
# Translated text: vad heter du
# Listening...
# Text recognized: aapka naam kya hai
# Translated text: Vad heter du
# Listening...
# Text recognized: my name is Mihir Ranjan
# Translated text: Jag heter Mihir Ranjan
# Listening...
# Text recognized: mera naam Mihir Ranjan hai
# Translated text: Jag heter Mihir Ranjan
# Listening...
# Text recognized: naa peru Mihir Ranjan
# Translated text: Jag heter Mihir Ramadan
# Listening...
# Text recognized: stop program
# Translated text: stoppprogram
# Stop command recognized. Exiting program.

# %%
#you say "take1" the language name and then speak you language it will translate
import speech_recognition as sr
import time
from googletrans import Translator

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translation."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=4)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(0.1)

if __name__ == "__main__":
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please tell the language in which you want to translate:")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
# Out:
# Please tell the language in which you want to translate:
# Language spoken: German
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: my name is Mihir Ranjan
# Translated text: Mein Name ist Mihir Ranjan
# Listening...
# Text recognized: mera naam hir Ranjan hai
# Translated text: Mein Name ist Hir Ranjan
# Listening...
# Text recognized: Naa Peru
# Translated text: Mein Name
# Listening...
# Text recognized: stop program
# Translated text: Programm beenden
# Stop command recognized. Exiting program.

# %%
#you say "take2" the language name and then speak you language it will translate
import speech_recognition as sr
import time
from googletrans import Translator

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translation."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=4)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(0.1)

if __name__ == "__main__":
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please tell the language in which you want to translate:")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
# Out:
# Please tell the language in which you want to translate:
# Language spoken: English
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: my name is Mihir
# Translated text: my name is Mihir
# Listening...
# Text recognized: mera naam Mihir
# Translated text: My name is mihir
# Listening...
# Text recognized: naa peru Mihir
# Translated text: My name is Mihir
# Listening...
# Text recognized: main Mihir Ranjan hun
# Translated text: I am Mihir Ranjan Hun
# Listening...
# Text recognized: tum kaun ho
# Translated text: Who are you
# Listening...
# Text recognized: main Mihir Ranjan hun
# Translated text: I am Mihir Ranjan Hun
# Listening...
# Text recognized: kya tum mere dost banoge
# Translated text: Will you be my friend
# Listening...
# Text recognized: stop program
# Translated text: stop program
# Stop command recognized. Exiting program.

# %%
pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from gtts) (2.28.2)
# Requirement already satisfied: click<8.2,>=7.1 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from gtts) (8.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/doctorranjan/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2022.12.7)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#saves the file locally and sepak
import speech_recognition as sr
import time
from googletrans import Translator
from gtts import gTTS
import os
import platform

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def play_audio(file_path):
    """Play audio file depending on the operating system."""
    if platform.system() == 'Windows':
        os.system(f"start {file_path}")
    elif platform.system() == 'Darwin':  # macOS
        os.system(f"open {file_path}")
    else:  # Assume Linux
        os.system(f"xdg-open {file_path}")

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translate text to speech in target language."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=5)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=4)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                # Convert the translated text to speech
                tts = gTTS(text=translated_text, lang=target_language_code)
                audio_file = "translated_audio.mp3"
                tts.save(audio_file)
                
                # Play the translated audio
                play_audio(audio_file)

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(2)

if __name__ == "__main__":
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please tell the language in which you want to translate:")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
# Out:
# Please tell the language in which you want to translate:
# Language spoken: French
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Text recognized: tum kaun ho
# Translated text: Qui es-tu
# Listening...
# Text recognized: mera naam Mihir Ranjan hai
# Translated text: Je m'appelle Mihir Ranjan
# Listening...
# Text recognized: Main Kaun hun
# Translated text: Qui suis je
# Listening...
# Text recognized: tum kaun ho bhai
# Translated text: Qui êtes-vous frère
# Listening...
# Text recognized: main Mahindra University ka student hun
# Translated text: Je suis étudiant de l'Université Mahindra
# Listening...
# Text recognized: stop program
# Translated text: programme d'arrêt
# Stop command recognized. Exiting program.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Collecting pyobjc>=2.4
#   Downloading pyobjc-10.3.1-py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-IOBluetooth==10.3.1
#   Downloading pyobjc_framework_IOBluetooth-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 1.4 MB/s eta 0:00:00
# Collecting pyobjc-framework-AppleScriptObjC==10.3.1
#   Downloading pyobjc_framework_AppleScriptObjC-10.3.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-Photos==10.3.1
#   Downloading pyobjc_framework_Photos-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-ModelIO==10.3.1
#   Downloading pyobjc_framework_ModelIO-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (21 kB)
# Collecting pyobjc-framework-ContactsUI==10.3.1
#   Downloading pyobjc_framework_ContactsUI-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (7.9 kB)
# Collecting pyobjc-framework-CoreHaptics==10.3.1
#   Downloading pyobjc_framework_CoreHaptics-10.3.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==10.3.1
#   Downloading pyobjc_framework_LatentSemanticMapping-10.3.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-CryptoTokenKit==10.3.1
#   Downloading pyobjc_framework_CryptoTokenKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-PassKit==10.3.1
#   Downloading pyobjc_framework_PassKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-GameplayKit==10.3.1
#   Downloading pyobjc_framework_GameplayKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-FinderSync==10.3.1
#   Downloading pyobjc_framework_FinderSync-10.3.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-PencilKit==10.3.1
#   Downloading pyobjc_framework_PencilKit-10.3.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-AudioVideoBridging==10.3.1
#   Downloading pyobjc_framework_AudioVideoBridging-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (11 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==10.3.1
#   Downloading pyobjc_framework_UniformTypeIdentifiers-10.3.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==10.3.1
#   Downloading pyobjc_framework_MultipeerConnectivity-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-FileProviderUI==10.3.1
#   Downloading pyobjc_framework_FileProviderUI-10.3.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CalendarStore==10.3.1
#   Downloading pyobjc_framework_CalendarStore-10.3.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-ScreenTime==10.3.1
#   Downloading pyobjc_framework_ScreenTime-10.3.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-MediaAccessibility==10.3.1
#   Downloading pyobjc_framework_MediaAccessibility-10.3.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-Contacts==10.3.1
#   Downloading pyobjc_framework_Contacts-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-ExceptionHandling==10.3.1
#   Downloading pyobjc_framework_ExceptionHandling-10.3.1-py2.py3-none-any.whl (6.7 kB)
# Collecting pyobjc-framework-libdispatch==10.3.1
#   Downloading pyobjc_framework_libdispatch-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (20 kB)
# Collecting pyobjc-framework-Network==10.3.1
#   Downloading pyobjc_framework_Network-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (19 kB)
# Collecting pyobjc-framework-CoreData==10.3.1
#   Downloading pyobjc_framework_CoreData-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (16 kB)
# Collecting pyobjc-framework-GameController==10.3.1
#   Downloading pyobjc_framework_GameController-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (20 kB)
# Collecting pyobjc-framework-StoreKit==10.3.1
#   Downloading pyobjc_framework_StoreKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-iTunesLibrary==10.3.1
#   Downloading pyobjc_framework_iTunesLibrary-10.3.1-py2.py3-none-any.whl (4.8 kB)
# Collecting pyobjc-framework-PhotosUI==10.3.1
#   Downloading pyobjc_framework_PhotosUI-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-AddressBook==10.3.1
#   Downloading pyobjc_framework_AddressBook-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-AdSupport==10.3.1
#   Downloading pyobjc_framework_AdSupport-10.3.1-py2.py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-UserNotificationsUI==10.3.1
#   Downloading pyobjc_framework_UserNotificationsUI-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-MailKit==10.3.1
#   Downloading pyobjc_framework_MailKit-10.3.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-SpriteKit==10.3.1
#   Downloading pyobjc_framework_SpriteKit-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (17 kB)
# Collecting pyobjc-framework-DVDPlayback==10.3.1
#   Downloading pyobjc_framework_DVDPlayback-10.3.1-py2.py3-none-any.whl (7.8 kB)
# Collecting pyobjc-framework-EventKit==10.3.1
#   Downloading pyobjc_framework_EventKit-10.3.1-py2.py3-none-any.whl (6.4 kB)
# Collecting pyobjc-framework-SystemConfiguration==10.3.1
#   Downloading pyobjc_framework_SystemConfiguration-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (21 kB)
# Collecting pyobjc-framework-Social==10.3.1
#   Downloading pyobjc_framework_Social-10.3.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-SecurityFoundation==10.3.1
#   Downloading pyobjc_framework_SecurityFoundation-10.3.1-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-Virtualization==10.3.1
#   Downloading pyobjc_framework_Virtualization-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-MapKit==10.3.1
#   Downloading pyobjc_framework_MapKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (22 kB)
# Collecting pyobjc-framework-ShazamKit==10.3.1
#   Downloading pyobjc_framework_ShazamKit-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (8.6 kB)
# Collecting pyobjc-framework-DeviceCheck==10.3.1
#   Downloading pyobjc_framework_DeviceCheck-10.3.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-KernelManagement==10.3.1
#   Downloading pyobjc_framework_KernelManagement-10.3.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-IntentsUI==10.3.1
#   Downloading pyobjc_framework_IntentsUI-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (9.6 kB)
# Collecting pyobjc-framework-LinkPresentation==10.3.1
#   Downloading pyobjc_framework_LinkPresentation-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-CoreWLAN==10.3.1
#   Downloading pyobjc_framework_CoreWLAN-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-Collaboration==10.3.1
#   Downloading pyobjc_framework_Collaboration-10.3.1-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-CallKit==10.3.1
#   Downloading pyobjc_framework_CallKit-10.3.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-CoreLocation==10.3.1
#   Downloading pyobjc_framework_CoreLocation-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-SoundAnalysis==10.3.1
#   Downloading pyobjc_framework_SoundAnalysis-10.3.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-Intents==10.3.1
#   Downloading pyobjc_framework_Intents-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (32 kB)
# Collecting pyobjc-framework-ScriptingBridge==10.3.1
#   Downloading pyobjc_framework_ScriptingBridge-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.4 kB)
# Collecting pyobjc-framework-Quartz==10.3.1
#   Downloading pyobjc_framework_Quartz-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.2/227.2 kB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting pyobjc-framework-AuthenticationServices==10.3.1
#   Downloading pyobjc_framework_AuthenticationServices-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (19 kB)
# Collecting pyobjc-framework-SafariServices==10.3.1
#   Downloading pyobjc_framework_SafariServices-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (7.4 kB)
# Collecting pyobjc-framework-Metal==10.3.1
#   Downloading pyobjc_framework_Metal-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 1.6 MB/s eta 0:00:00
# Collecting pyobjc-framework-ScreenCaptureKit==10.3.1
#   Downloading pyobjc_framework_ScreenCaptureKit-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (11 kB)
# Collecting pyobjc-framework-CoreAudioKit==10.3.1
#   Downloading pyobjc_framework_CoreAudioKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (7.3 kB)
# Collecting pyobjc-framework-CoreBluetooth==10.3.1
#   Downloading pyobjc_framework_CoreBluetooth-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (14 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==10.3.1
#   Downloading pyobjc_framework_AppTrackingTransparency-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-CoreServices==10.3.1
#   Downloading pyobjc_framework_CoreServices-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (29 kB)
# Collecting pyobjc-framework-Vision==10.3.1
#   Downloading pyobjc_framework_Vision-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (17 kB)
# Collecting pyobjc-framework-AppleScriptKit==10.3.1
#   Downloading pyobjc_framework_AppleScriptKit-10.3.1-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-DiskArbitration==10.3.1
#   Downloading pyobjc_framework_DiskArbitration-10.3.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-DiscRecording==10.3.1
#   Downloading pyobjc_framework_DiscRecording-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (14 kB)
# Collecting pyobjc-framework-CoreMediaIO==10.3.1
#   Downloading pyobjc_framework_CoreMediaIO-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (17 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==10.3.1
#   Downloading pyobjc_framework_VideoSubscriberAccount-10.3.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==10.3.1
#   Downloading pyobjc_framework_MetalPerformanceShaders-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (33 kB)
# Collecting pyobjc-framework-InstantMessage==10.3.1
#   Downloading pyobjc_framework_InstantMessage-10.3.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pyobjc-framework-NetFS==10.3.1
#   Downloading pyobjc_framework_NetFS-10.3.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-ReplayKit==10.3.1
#   Downloading pyobjc_framework_ReplayKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-PreferencePanes==10.3.1
#   Downloading pyobjc_framework_PreferencePanes-10.3.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-Cocoa==10.3.1
#   Downloading pyobjc_framework_Cocoa-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (396 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.2/396.2 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting pyobjc-framework-MediaLibrary==10.3.1
#   Downloading pyobjc_framework_MediaLibrary-10.3.1-py2.py3-none-any.whl (4.0 kB)
# Collecting pyobjc-framework-CoreSpotlight==10.3.1
#   Downloading pyobjc_framework_CoreSpotlight-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (9.6 kB)
# Collecting pyobjc-framework-SearchKit==10.3.1
#   Downloading pyobjc_framework_SearchKit-10.3.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CFNetwork==10.3.1
#   Downloading pyobjc_framework_CFNetwork-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (18 kB)
# Collecting pyobjc-framework-InstallerPlugins==10.3.1
#   Downloading pyobjc_framework_InstallerPlugins-10.3.1-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-ScreenSaver==10.3.1
#   Downloading pyobjc_framework_ScreenSaver-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.0 kB)
# Collecting pyobjc-framework-Accounts==10.3.1
#   Downloading pyobjc_framework_Accounts-10.3.1-py2.py3-none-any.whl (4.7 kB)
# Collecting pyobjc-framework-Security==10.3.1
#   Downloading pyobjc_framework_Security-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.4 MB/s eta 0:00:00
# Collecting pyobjc-framework-NotificationCenter==10.3.1
#   Downloading pyobjc_framework_NotificationCenter-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-OSLog==10.3.1
#   Downloading pyobjc_framework_OSLog-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (7.9 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==10.3.1
#   Downloading pyobjc_framework_MetalPerformanceShadersGraph-10.3.1-py2.py3-none-any.whl (6.0 kB)
# Collecting pyobjc-framework-CoreMedia==10.3.1
#   Downloading pyobjc_framework_CoreMedia-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (29 kB)
# Collecting pyobjc-framework-Speech==10.3.1
#   Downloading pyobjc_framework_Speech-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (9.1 kB)
# Collecting pyobjc-framework-InputMethodKit==10.3.1
#   Downloading pyobjc_framework_InputMethodKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (9.5 kB)
# Collecting pyobjc-framework-NetworkExtension==10.3.1
#   Downloading pyobjc_framework_NetworkExtension-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-ExternalAccessory==10.3.1
#   Downloading pyobjc_framework_ExternalAccessory-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.9 kB)
# Collecting pyobjc-framework-Accessibility==10.3.1
#   Downloading pyobjc_framework_Accessibility-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-CoreText==10.3.1
#   Downloading pyobjc_framework_CoreText-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (30 kB)
# Collecting pyobjc-framework-MetricKit==10.3.1
#   Downloading pyobjc_framework_MetricKit-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (8.2 kB)
# Collecting pyobjc-framework-BusinessChat==10.3.1
#   Downloading pyobjc_framework_BusinessChat-10.3.1-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-SystemExtensions==10.3.1
#   Downloading pyobjc_framework_SystemExtensions-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.7 kB)
# Collecting pyobjc-framework-ExecutionPolicy==10.3.1
#   Downloading pyobjc_framework_ExecutionPolicy-10.3.1-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-MediaToolbox==10.3.1
#   Downloading pyobjc_framework_MediaToolbox-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-LocalAuthentication==10.3.1
#   Downloading pyobjc_framework_LocalAuthentication-10.3.1-py2.py3-none-any.whl (5.7 kB)
# Collecting pyobjc-framework-ApplicationServices==10.3.1
#   Downloading pyobjc_framework_ApplicationServices-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (31 kB)
# Collecting pyobjc-framework-SecurityInterface==10.3.1
#   Downloading pyobjc_framework_SecurityInterface-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-MetalKit==10.3.1
#   Downloading pyobjc_framework_MetalKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.8 kB)
# Collecting pyobjc-framework-ClassKit==10.3.1
#   Downloading pyobjc_framework_ClassKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.4 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==10.3.1
#   Downloading pyobjc_framework_AutomaticAssessmentConfiguration-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.6 kB)
# Collecting pyobjc-framework-ImageCaptureCore==10.3.1
#   Downloading pyobjc_framework_ImageCaptureCore-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (16 kB)
# Collecting pyobjc-framework-DiscRecordingUI==10.3.1
#   Downloading pyobjc_framework_DiscRecordingUI-10.3.1-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-CloudKit==10.3.1
#   Downloading pyobjc_framework_CloudKit-10.3.1-py2.py3-none-any.whl (10 kB)
# Collecting pyobjc-framework-ColorSync==10.3.1
#   Downloading pyobjc_framework_ColorSync-10.3.1-py2.py3-none-any.whl (5.6 kB)
# Collecting pyobjc-framework-AVKit==10.3.1
#   Downloading pyobjc_framework_AVKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-CoreMIDI==10.3.1
#   Downloading pyobjc_framework_CoreMIDI-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (17 kB)
# Collecting pyobjc-framework-IOBluetoothUI==10.3.1
#   Downloading pyobjc_framework_IOBluetoothUI-10.3.1-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-GameCenter==10.3.1
#   Downloading pyobjc_framework_GameCenter-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (19 kB)
# Collecting pyobjc-framework-UserNotifications==10.3.1
#   Downloading pyobjc_framework_UserNotifications-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (9.7 kB)
# Collecting pyobjc-framework-DataDetection==10.3.1
#   Downloading pyobjc_framework_DataDetection-10.3.1-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-FSEvents==10.3.1
#   Downloading pyobjc_framework_FSEvents-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (13 kB)
# Collecting pyobjc-framework-WebKit==10.3.1
#   Downloading pyobjc_framework_WebKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.3 MB/s eta 0:00:00
# Collecting pyobjc-framework-SyncServices==10.3.1
#   Downloading pyobjc_framework_SyncServices-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (14 kB)
# Collecting pyobjc-framework-PHASE==10.3.1
#   Downloading pyobjc_framework_PHASE-10.3.1-py2.py3-none-any.whl (6.2 kB)
# Collecting pyobjc-framework-CoreAudio==10.3.1
#   Downloading pyobjc_framework_CoreAudio-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (35 kB)
# Collecting pyobjc-framework-ServiceManagement==10.3.1
#   Downloading pyobjc_framework_ServiceManagement-10.3.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-AVFoundation==10.3.1
#   Downloading pyobjc_framework_AVFoundation-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 2.1 MB/s eta 0:00:00
# Collecting pyobjc-framework-libxpc==10.3.1
#   Downloading pyobjc_framework_libxpc-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (19 kB)
# Collecting pyobjc-framework-OSAKit==10.3.1
#   Downloading pyobjc_framework_OSAKit-10.3.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-MLCompute==10.3.1
#   Downloading pyobjc_framework_MLCompute-10.3.1-py2.py3-none-any.whl (6.4 kB)
# Collecting pyobjc-framework-FileProvider==10.3.1
#   Downloading pyobjc_framework_FileProvider-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (18 kB)
# Collecting pyobjc-framework-OpenDirectory==10.3.1
#   Downloading pyobjc_framework_OpenDirectory-10.3.1-py2.py3-none-any.whl (11 kB)
# Collecting pyobjc-framework-MediaPlayer==10.3.1
#   Downloading pyobjc_framework_MediaPlayer-10.3.1-py2.py3-none-any.whl (6.5 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==10.3.1
#   Downloading pyobjc_framework_QuickLookThumbnailing-10.3.1-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-NaturalLanguage==10.3.1
#   Downloading pyobjc_framework_NaturalLanguage-10.3.1-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-core==10.3.1
#   Downloading pyobjc_core-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.3/774.3 kB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting pyobjc-framework-SceneKit==10.3.1
#   Downloading pyobjc_framework_SceneKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (32 kB)
# Collecting pyobjc-framework-GameKit==10.3.1
#   Downloading pyobjc_framework_GameKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (22 kB)
# Collecting pyobjc-framework-Automator==10.3.1
#   Downloading pyobjc_framework_Automator-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (10 kB)
# Collecting pyobjc-framework-AdServices==10.3.1
#   Downloading pyobjc_framework_AdServices-10.3.1-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-VideoToolbox==10.3.1
#   Downloading pyobjc_framework_VideoToolbox-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (12 kB)
# Collecting pyobjc-framework-LaunchServices==10.3.1
#   Downloading pyobjc_framework_LaunchServices-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-CoreML==10.3.1
#   Downloading pyobjc_framework_CoreML-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (11 kB)
# Collecting pyobjc-framework-CoreMotion==10.3.1
#   Downloading pyobjc_framework_CoreMotion-10.3.1-cp310-cp310-macosx_10_9_universal2.whl (9.8 kB)
# Collecting pyobjc-framework-DictionaryServices==10.3.1
#   Downloading pyobjc_framework_DictionaryServices-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==10.3.1
#   Downloading pyobjc_framework_LocalAuthenticationEmbeddedUI-10.3.1-py2.py3-none-any.whl (3.6 kB)
# Collecting pyobjc-framework-IOSurface==10.3.1
#   Downloading pyobjc_framework_IOSurface-10.3.1-py2.py3-none-any.whl (4.6 kB)
# Collecting pyobjc-framework-PushKit==10.3.1
#   Downloading pyobjc_framework_PushKit-10.3.1-cp36-abi3-macosx_10_13_universal2.whl (8.2 kB)
# Installing collected packages: pyobjc-core, pyobjc-framework-Cocoa, pyobjc-framework-WebKit, pyobjc-framework-Virtualization, pyobjc-framework-VideoSubscriberAccount, pyobjc-framework-UserNotifications, pyobjc-framework-UniformTypeIdentifiers, pyobjc-framework-SystemExtensions, pyobjc-framework-SystemConfiguration, pyobjc-framework-StoreKit, pyobjc-framework-Speech, pyobjc-framework-SoundAnalysis, pyobjc-framework-Social, pyobjc-framework-ShazamKit, pyobjc-framework-ServiceManagement, pyobjc-framework-Security, pyobjc-framework-ScriptingBridge, pyobjc-framework-ScreenTime, pyobjc-framework-ScreenSaver, pyobjc-framework-SafariServices, pyobjc-framework-ReplayKit, pyobjc-framework-Quartz, pyobjc-framework-PushKit, pyobjc-framework-PreferencePanes, pyobjc-framework-PhotosUI, pyobjc-framework-Photos, pyobjc-framework-PencilKit, pyobjc-framework-PassKit, pyobjc-framework-OSAKit, pyobjc-framework-OpenDirectory, pyobjc-framework-NotificationCenter, pyobjc-framework-NetworkExtension, pyobjc-framework-Network, pyobjc-framework-NetFS, pyobjc-framework-NaturalLanguage, pyobjc-framework-MultipeerConnectivity, pyobjc-framework-MLCompute, pyobjc-framework-MetricKit, pyobjc-framework-Metal, pyobjc-framework-MediaToolbox, pyobjc-framework-MediaAccessibility, pyobjc-framework-MailKit, pyobjc-framework-libxpc, pyobjc-framework-libdispatch, pyobjc-framework-LatentSemanticMapping, pyobjc-framework-KernelManagement, pyobjc-framework-iTunesLibrary, pyobjc-framework-IOSurface, pyobjc-framework-IOBluetooth, pyobjc-framework-Intents, pyobjc-framework-InstallerPlugins, pyobjc-framework-InputMethodKit, pyobjc-framework-ImageCaptureCore, pyobjc-framework-GameController, pyobjc-framework-GameCenter, pyobjc-framework-FSEvents, pyobjc-framework-FinderSync, pyobjc-framework-FileProvider, pyobjc-framework-ExternalAccessory, pyobjc-framework-ExecutionPolicy, pyobjc-framework-ExceptionHandling, pyobjc-framework-EventKit, pyobjc-framework-DVDPlayback, pyobjc-framework-DiskArbitration, pyobjc-framework-DiscRecording, pyobjc-framework-DeviceCheck, pyobjc-framework-DataDetection, pyobjc-framework-CryptoTokenKit, pyobjc-framework-CoreWLAN, pyobjc-framework-CoreSpotlight, pyobjc-framework-CoreMotion, pyobjc-framework-CoreML, pyobjc-framework-CoreMIDI, pyobjc-framework-CoreMediaIO, pyobjc-framework-CoreMedia, pyobjc-framework-CoreLocation, pyobjc-framework-CoreHaptics, pyobjc-framework-CoreData, pyobjc-framework-CoreBluetooth, pyobjc-framework-CoreAudio, pyobjc-framework-Contacts, pyobjc-framework-ColorSync, pyobjc-framework-Collaboration, pyobjc-framework-ClassKit, pyobjc-framework-CFNetwork, pyobjc-framework-CallKit, pyobjc-framework-CalendarStore, pyobjc-framework-BusinessChat, pyobjc-framework-Automator, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-AuthenticationServices, pyobjc-framework-AudioVideoBridging, pyobjc-framework-AppTrackingTransparency, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AppleScriptKit, pyobjc-framework-AdSupport, pyobjc-framework-AdServices, pyobjc-framework-AddressBook, pyobjc-framework-Accounts, pyobjc-framework-Vision, pyobjc-framework-VideoToolbox, pyobjc-framework-UserNotificationsUI, pyobjc-framework-SyncServices, pyobjc-framework-SpriteKit, pyobjc-framework-SecurityInterface, pyobjc-framework-SecurityFoundation, pyobjc-framework-ScreenCaptureKit, pyobjc-framework-SceneKit, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-OSLog, pyobjc-framework-ModelIO, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-MetalKit, pyobjc-framework-MediaLibrary, pyobjc-framework-MapKit, pyobjc-framework-LocalAuthentication, pyobjc-framework-LinkPresentation, pyobjc-framework-IOBluetoothUI, pyobjc-framework-IntentsUI, pyobjc-framework-InstantMessage, pyobjc-framework-GameKit, pyobjc-framework-FileProviderUI, pyobjc-framework-DiscRecordingUI, pyobjc-framework-CoreText, pyobjc-framework-CoreServices, pyobjc-framework-CoreAudioKit, pyobjc-framework-ContactsUI, pyobjc-framework-CloudKit, pyobjc-framework-AVKit, p ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 9.0
#     Uninstalling pyobjc-core-9.0:
#       Successfully uninstalled pyobjc-core-9.0
#   Attempting uninstall: pyobjc-framework-Cocoa
#     Found existing installation: pyobjc-framework-Cocoa 9.0
#     Uninstalling pyobjc-framework-Cocoa-9.0:
#       Successfully uninstalled pyobjc-framework-Cocoa-9.0
#   Attempting uninstall: pyobjc-framework-FSEvents
#     Found existing installation: pyobjc-framework-FSEvents 9.0
#     Uninstalling pyobjc-framework-FSEvents-9.0:
#       Successfully uninstalled pyobjc-framework-FSEvents-9.0
#   Attempting uninstall: pyobjc-framework-CoreServices
#     Found existing installation: pyobjc-framework-CoreServices 9.0
#     Uninstalling pyobjc-framework-CoreServices-9.0:
#       Successfully uninstalled pyobjc-framework-CoreServices-9.0
# Successfully installed pyobjc-10.3.1 pyobjc-core-10.3.1 pyobjc-framework-AVFoundation-10.3.1 pyobjc-framework-AVKit-10.3.1 pyobjc-framework-Accessibility-10.3.1 pyobjc-framework-Accounts-10.3.1 pyobjc-framework-AdServices-10.3.1 pyobjc-framework-AdSupport-10.3.1 pyobjc-framework-AddressBook-10.3.1 pyobjc-framework-AppTrackingTransparency-10.3.1 pyobjc-framework-AppleScriptKit-10.3.1 pyobjc-framework-AppleScriptObjC-10.3.1 pyobjc-framework-ApplicationServices-10.3.1 pyobjc-framework-AudioVideoBridging-10.3.1 pyobjc-framework-AuthenticationServices-10.3.1 pyobjc-framework-AutomaticAssessmentConfiguration-10.3.1 pyobjc-framework-Automator-10.3.1 pyobjc-framework-BusinessChat-10.3.1 pyobjc-framework-CFNetwork-10.3.1 pyobjc-framework-CalendarStore-10.3.1 pyobjc-framework-CallKit-10.3.1 pyobjc-framework-ClassKit-10.3.1 pyobjc-framework-CloudKit-10.3.1 pyobjc-framework-Cocoa-10.3.1 pyobjc-framework-Collaboration-10.3.1 pyobjc-framework-ColorSync-10.3.1 pyobjc-framework-Contacts-10.3.1 pyobjc-framework-ContactsUI-10.3.1 pyobjc-framework-CoreAudio-10.3.1 pyobjc-framework-CoreAudioKit-10.3.1 pyobjc-framework-CoreBluetooth-10.3.1 pyobjc-framework-CoreData-10.3.1 pyobjc-framework-CoreHaptics-10.3.1 pyobjc-framework-CoreLocation-10.3.1 pyobjc-framework-CoreMIDI-10.3.1 pyobjc-framework-CoreML-10.3.1 pyobjc-framework-CoreMedia-10.3.1 pyobjc-framework-CoreMediaIO-10.3.1 pyobjc-framework-CoreMotion-10.3.1 pyobjc-framework-CoreServices-10.3.1 pyobjc-framework-CoreSpotlight-10.3.1 pyobjc-framework-CoreText-10.3.1 pyobjc-framework-CoreWLAN-10.3.1 pyobjc-framework-CryptoTokenKit-10.3.1 pyobjc-framework-DVDPlayback-10.3.1 pyobjc-framework-DataDetection-10.3.1 pyobjc-framework-DeviceCheck-10.3.1 pyobjc-framework-DictionaryServices-10.3.1 pyobjc-framework-DiscRecording-10.3.1 pyobjc-framework-DiscRecordingUI-10.3.1 pyobjc-framework-DiskArbitration-10.3.1 pyobjc-framework-EventKit-10.3.1 pyobjc-framework-ExceptionHandling-10.3.1 pyobjc-framework-ExecutionPolicy-10.3.1 pyobjc-framework-ExternalAccessory-10.3.1 pyobjc-framework-FSEvents-10.3.1 pyobjc-framework-FileProvider-10.3.1 pyobjc-framework-FileProviderUI-10.3.1 pyobjc-framework-FinderSync-10.3.1 pyobjc-framework-GameCenter-10.3.1 pyobjc-framework-GameController-10.3.1 pyobjc-framework-GameKit-10.3.1 pyobjc-framework-GameplayKit-10.3.1 pyobjc-framework-IOBluetooth-10.3.1 pyobjc-framework-IOBluetoothUI-10.3.1 pyobjc-framework-IOSurface-10.3.1 pyobjc-framework-ImageCaptureCore-10.3.1 pyobjc-framework-InputMethodKit-10.3.1 pyobjc-framework-InstallerPlugins-10.3.1 pyobjc-framework-InstantMessage-10.3.1 pyobjc-framework-Intents-10.3.1 pyobjc-framework-IntentsUI-10.3.1 pyobjc-framework-KernelManagement-10.3.1 pyobjc-framework-LatentSemanticMapping-10.3.1 pyobjc-framework-LaunchServices-10.3.1 pyobjc-framework-LinkPresentation-10.3.1 pyobjc-framework-LocalAuthentication-10.3.1 pyobjc-framework-LocalAuthenticationEmbeddedUI-10.3.1 pyobjc-framework-MLCompute-10.3.1 pyobjc-framework-MailKit-10.3.1 pyobjc-framework-MapKit-10.3.1 pyobjc-framework-MediaAccessibility-10.3.1 pyobjc-framework-MediaLibrary-10.3.1 pyobjc-framework-MediaPlayer-10.3.1 pyobjc-framework-MediaToolbox-10.3.1 pyobjc-framework-Metal-10.3.1 pyobjc-framework-MetalKit-10.3.1 pyobjc-framework-MetalPerformanceShaders-10.3.1 pyobjc-framework-MetalPerformanceShadersGraph-10.3.1 pyobjc-framework-MetricKit-10.3.1 pyobjc-framework-ModelIO-10.3.1 pyobjc-framework-MultipeerConnectivity-10.3.1 pyobjc-framework-NaturalLanguage-10.3.1 pyobjc-framework-NetFS-10.3.1 pyobjc-framework-Network-10.3.1 pyobjc-framework-NetworkExtension-10.3.1 pyobjc-framework-NotificationCenter-10.3.1 pyobjc-framework-OSAKit-10.3.1 pyobjc-framework-OSLog-10.3.1 pyobjc-framework-OpenDirectory-10.3.1 pyobjc-framework-PHASE-10.3.1 pyobjc-framework-PassKit-10.3.1 pyobjc-framework-PencilKit-10.3.1 pyobjc-framework-Photos-10.3.1 pyobjc-framework-PhotosUI-10.3.1 pyobjc-framework-PreferencePanes-10.3.1 pyobjc-framework-PushKit-10.3.1 pyobjc-framework-Quartz-10.3.1 pyobjc-framework-Quic ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#code to put give locally not saving in device but temp file saving and deleting it
import speech_recognition as sr
import time
from googletrans import Translator
from gtts import gTTS
import os
import tempfile
import platform

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def speak_text(text, lang_code):
    """Convert text to speech and play it directly."""
    tts = gTTS(text=text, lang=lang_code)
    with tempfile.NamedTemporaryFile(delete=True) as temp_file:
        tts.save(temp_file.name)
        os.system(f"start {temp_file.name}" if platform.system() == "Windows" else f"afplay {temp_file.name}" if platform.system() == "Darwin" else f"mpg123 {temp_file.name}")

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translate text to speech in target language."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=4)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=3)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                # Convert the translated text to speech and speak it
                speak_text(translated_text, target_language_code)

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(1)

if __name__ == "__main__":
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please tell the language in which you want to translate:")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
# Out:
# Please tell the language in which you want to translate:
# Language spoken: Japanese
# Please wait. Calibrating microphone...
# Microphone calibrated. Start speaking...
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: Daksh randi hai
# Translated text: ダクシャは売春婦です
# Listening...
# Text recognized: Daksh Se Bada Harami koi hai hi Nahin
# Translated text: ダクシャほど大きなろくでなしはありません
# Listening...
# Text recognized: Daksh chhakka hai
# Translated text: 熟練した6です
# Listening...
# Text recognized: Daksh is gay
# Translated text: ダクシャこのゲイ
# Listening...
# Text recognized: Daksh has small penis
# Translated text: ダクシュには小さなペニスがあります
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Could not understand the audio
# Listening...
# Text recognized: stop program
# Translated text: プログラムを停止します
# Stop command recognized. Exiting program.

# %%
#code to put give locally not saving in device but temp file saving and deleting it
import speech_recognition as sr
import time
from googletrans import Translator
from gtts import gTTS
import os
import tempfile
import platform

# Dictionary to map spoken language names to language codes
language_map = {
    'afrikaans': 'af', 'albanian': 'sq', 'arabic': 'ar', 'armenian': 'hy', 'bengali': 'bn', 'bosnian': 'bs',
    'catalan': 'ca', 'chechen': 'ce', 'chichewa': 'ny', 'chinese simplified': 'zh-cn', 'chinese traditional': 'zh-tw',
    'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo',
    'estonian': 'et', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka',
    'german': 'de', 'greek': 'el', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'he',
    'hindi': 'hi', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'indonesian': 'id', 'interlingua': 'ia', 'interlingue': 'ie',
    'inuktitut': 'iu', 'irish': 'ie', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk',
    'khmer': 'km', 'kinyarwanda': 'ki', 'korean': 'ko', 'kurdish': 'ku', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv',
    'lithuanian': 'lt', 'luxembourgish': 'lb', 'macedonian': 'mk', 'malagasy': 'mg', 'malayalam': 'ml', 'maltese': 'mt',
    'maori': 'mi', 'marathi': 'mr', 'myanmar': 'my', 'mongolian': 'mn', 'nepali': 'my', 'norwegian': 'no', 'odia': 'or',
    'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro',
    'russian': 'ru', 'samoan': 'sm', 'sango': 'sg', 'sanskrit': 'sa', 'sardinian': 'sc', 'serbian': 'sr', 'sesotho': 'st',
    'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es',
    'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tagalog': 'tl', 'tajik': 'tg', 'tamil': 'ta', 'telugu': 'te',
    'thai': 'th', 'tigrinya': 'ti', 'tonga': 'to', 'turkish': 'tr', 'ukrainian': 'uk', 'urdu': 'ur', 'vietnamese': 'vi',
    'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'
}

def get_language_code(language_name):
    """Convert spoken language name to language code."""
    language_name = language_name.lower()
    return language_map.get(language_name, None)

def speak_text(text, lang_code):
    """Convert text to speech and play it directly."""
    tts = gTTS(text=text, lang=lang_code)
    with tempfile.NamedTemporaryFile(delete=True) as temp_file:
        tts.save(temp_file.name)
        os.system(f"start {temp_file.name}" if platform.system() == "Windows" else f"afplay {temp_file.name}" if platform.system() == "Darwin" else f"mpg123 {temp_file.name}")

def real_time_speech_recognition(target_language_code):
    """Perform real-time speech recognition and translate text to speech in target language."""
    recognizer = sr.Recognizer()
    translator = Translator()

    with sr.Microphone() as source:
        print("Please wait. Calibrating microphone...")
        recognizer.adjust_for_ambient_noise(source, duration=1)
        print("Microphone calibrated. Start speaking...")

        while True:
            print("Listening...")
            audio = recognizer.record(source, duration=3.5)

            try:
                text = recognizer.recognize_google(audio)
                print(f"Text recognized: {text}")

                # Translate the recognized text
                translated_text = translator.translate(text, dest=target_language_code).text
                print(f"Translated text: {translated_text}")

                # Convert the translated text to speech and speak it
                speak_text(translated_text, target_language_code)

                if "stop program" in text.lower():
                    print("Stop command recognized. Exiting program.")
                    break
            except sr.RequestError as e:
                print(f"Could not request results; {e}")
            except sr.UnknownValueError:
                print("Could not understand the audio")

            time.sleep(0.10)

if __name__ == "__main__":
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please tell the language in which you want to translate:")
        audio = recognizer.listen(source)
    
    try:
        spoken_language = recognizer.recognize_google(audio)
        print(f"Language spoken: {spoken_language}")
        target_language_code = get_language_code(spoken_language)

        if target_language_code is None:
            print("Unsupported language. Exiting program.")
        else:
            real_time_speech_recognition(target_language_code)
    except sr.RequestError as e:
        print(f"Could not request results; {e}")
    except sr.UnknownValueError:
        print("Could not understand the audio")
